# %%
#import package
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker
from matplotlib import colors
from matplotlib.animation import FuncAnimation
from IPython import display, HTML

# %% [markdown]
# ### Load some paths

# %%
simple_path=r'C:/Users/22042055/OneDrive - The University of Western Australia/PhD/Conference_Abstract/OSM2024/figs/'
model_path=r'C:/Users/22042055/OneDrive - The University of Western Australia/MPhil/Thesis/Thesis_chapter2_figs/'

# %% [markdown]
# ### motivation (background)

# %%
# display .gif in jupyter notebook
# display.HTML('<img src="{}">'.format(simple_path+'SST_OSM_July_v2.gif'))
display.Image(url=simple_path+'SST_OSM_July_v2.gif')
# Out:
# <img src="C:/Users/22042055/OneDrive - The University of Western Australia/PhD/Conference_Abstract/OSM2024/figs/SST_OSM_July_v2.gif"/>

# %%
import os

# %%
os.listdir(simple_path)
# Out:
# ['0.jpg',
#  '1.jpg',
#  '2.jpg',
#  '20240213_073519942_iOS.png',
#  'Diffusivity_compare.jpg',
#  'eddy_development_NWS.gif',
#  'eddy_development_NWS.mp4',
#  'eddy_development_NWS2.gif',
#  'eddy_development_NWS3.gif',
#  'eddy_development_NW_fps_1.gif',
#  'IMG_0780.JPG',
#  'IMG_0781.JPG',
#  'IMG_0782.JPG',
#  'IMG_0783.JPG',
#  'IMG_0784.JPG',
#  'IMG_0785.JPG',
#  'IMG_0786.JPG',
#  'SST_OSM_July.gif',
#  'SST_OSM_July_Aug.gif',
#  'SST_OSM_July_tmin22.gif',
#  'SST_OSM_July_v2.gif']

# %% [markdown]
# ![NWS_infor.gif](SST_OSM_July_v2.gif)

# %% [markdown]
# ### general idea about 'baroclinic instability'

# %%
# general idea about `baroclinic instability'

# display.Image(simple_path+"IMG_0780.jpg")
example1_1 = display.Image(simple_path+'IMG_0780.jpg',width=200)
example1_2 = display.Image(simple_path+'IMG_0781.jpg',width=200)
example1_3 = display.Image(simple_path+'IMG_0782.jpg',width=200)
# fig=plt.figure(figsize=(5,5))
display.display(example1_1,example1_2,example1_3)

# %%
# display.Image(simple_path+"IMG_0780.jpg")
example2_1 = display.Image(simple_path+'IMG_0783.jpg',width=200)
example2_2 = display.Image(simple_path+'IMG_0784.jpg',width=200)
example2_3 = display.Image(simple_path+'IMG_0785.jpg',width=200)
example2_4 = display.Image(simple_path+'IMG_0786.jpg',width=200)

display.display(example2_1,example2_2,example2_3,example2_4)

# %% [markdown]
# ### model set up

# %%
display.Image(model_path+"Fig_2.jpg")

# %% [markdown]
# ### eddies from the model

# %% [markdown]
# ![NWS_infor.gif](eddy_development_NWS3.gif)
